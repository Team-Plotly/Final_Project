# %%
import pandas as pd

# %%
Income_df = pd.read_csv("finaltable.csv")
Income_df
# Out:
#       FIPS Code        County Name State  Median Household Income 2018  \
# 0          1001     Autauga County    AL                         59338
# 1          1003     Baldwin County    AL                         57588
# 2          1005     Barbour County    AL                         34382
# 3          1007        Bibb County    AL                         46064
# 4          1009      Blount County    AL                         50412
# ...         ...                ...   ...                           ...
# 3132      56037  Sweetwater County    WY                         73315
# 3133      56039       Teton County    WY                         99087
# 3134      56041       Uinta County    WY                         63401
# 3135      56043    Washakie County    WY                         55190
# 3136      56045      Weston County    WY                         54319
#
#       Unemployment Rate 2018  Population 2018  Education Percent 2018  \
# ...

# %%
Income_df.count()
# Out:
# FIPS Code                       3137
# County Name                     3137
# State                           3135
# Median Household Income 2018    3137
# Unemployment Rate 2018          3137
# Population 2018                 3137
# Education Percent 2018          3137
# Poverty Percent 2018            3137
# Pop per Sq Mile                 3136
# Average HH Size                 3136
# dtype: int64

# %%
Income_df.dropna()
# Out:
#       FIPS Code        County Name State  Median Household Income 2018  \
# 0          1001     Autauga County    AL                         59338
# 1          1003     Baldwin County    AL                         57588
# 2          1005     Barbour County    AL                         34382
# 3          1007        Bibb County    AL                         46064
# 4          1009      Blount County    AL                         50412
# ...         ...                ...   ...                           ...
# 3132      56037  Sweetwater County    WY                         73315
# 3133      56039       Teton County    WY                         99087
# 3134      56041       Uinta County    WY                         63401
# 3135      56043    Washakie County    WY                         55190
# 3136      56045      Weston County    WY                         54319
#
#       Unemployment Rate 2018  Population 2018  Education Percent 2018  \
# ...

# %%
Income_df.dtypes
# Out:
# FIPS Code                         int64
# County Name                      object
# State                            object
# Median Household Income 2018      int64
# Unemployment Rate 2018          float64
# Population 2018                   int64
# Education Percent 2018          float64
# Poverty Percent 2018            float64
# Pop per Sq Mile                 float64
# Average HH Size                 float64
# dtype: object

# %%
Income_df[["Median Household Income 2018"]].describe()
# Out:
#        Median Household Income 2018
# count                   3137.000000
# mean                   52812.295824
# std                    13886.937293
# min                    25385.000000
# 25%                    43688.000000
# 50%                    50576.000000
# 75%                    58855.000000
# max                   140382.000000

# %%
import seaborn as sn
import matplotlib.pyplot as plt

# %%
ax1 = Income_df.plot.scatter(x='Unemployment Rate 2018',
                      y='Median Household Income 2018',
                      c='DarkBlue')

# %%
ax2 = Income_df.plot.scatter(x='Population 2018',
                      y='Median Household Income 2018',
                      c='DarkBlue')

# %%
ax3 = Income_df.plot.scatter(x='Education Percent 2018',
                      y='Median Household Income 2018',
                      c='DarkBlue')

# %%
ax4 = Income_df.plot.scatter(x='Poverty Percent 2018',
                      y='Median Household Income 2018',
                      c='DarkBlue')

# %%
ax5 = Income_df.plot.scatter(x='Pop per Sq Mile',
                      y='Median Household Income 2018',
                      c='DarkBlue')

# %%
ax6 = Income_df.plot.scatter(x='Average HH Size',
                      y='Median Household Income 2018',
                      c='DarkBlue')

# %%
corrMatrix = Income_df.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %%
Final_Income = Income_df.drop(columns = ["FIPS Code", "County Name","State","Population 2018", "Pop per Sq Mile"])
Final_Income = Final_Income.dropna()
Final_Income
# Out:
#       Median Household Income 2018  Unemployment Rate 2018  \
# 0                            59338                     3.6
# 1                            57588                     3.6
# 2                            34382                     5.1
# 3                            46064                     3.9
# 4                            50412                     3.5
# ...                            ...                     ...
# 3132                         73315                     4.0
# 3133                         99087                     2.9
# 3134                         63401                     4.2
# 3135                         55190                     4.1
# 3136                         54319                     3.3
#
#       Education Percent 2018  Poverty Percent 2018  Average HH Size
# 0                       27.7                  13.8             2.68
# 1                       31.3                   9.8             2.46
# ...

# %%
sn.pairplot(Final_Income)

# %%
y = Final_Income["Median Household Income 2018"]
X = Final_Income.drop(columns = "Median Household Income 2018")

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

X_train.shape
# Out:
# (2352, 4)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(y_test, y_pred)
score
# Out:
# 0.8441182289361226

# %%
print(regressor.coef_)
# Out:
# [  222.77209379   676.82938744 -1302.79782334 18884.93904676]

# %%
print(regressor.intercept_)
# Out:
# 10200.2689373873
